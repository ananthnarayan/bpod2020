# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
# %matplotlib inline

# %%
data = pd.read_csv("run23.csv")

# %%
# # Sort Run - Set 1

set1 = data['Set'] == 'set1'
sort_run = data['Workload'] == 'sort_run'
sort_run = data[set1 & sort_run]
sort_run.reset_index(drop=True, inplace = True)
sort_run.plot(y='CPU', title = "sort_run_set1_CPU", use_index=True)
sort_run.plot(y='Mem', title = "sort_run_set1_Mem", use_index=True)

# Sort Run - Set 2

dataset = data['Set'] == 'set2'
sort_run = data['Workload'] == 'sort_run'
sort_run = data[dataset & sort_run]
sort_run.reset_index(drop=True, inplace = True)
sort_run.plot(y='CPU', title = "sort_run_set2_CPU", use_index=True)
sort_run.plot(y='Mem', title = "sort_run_set2_Mem", use_index=True)

# Sort Run - set3

dataset = data['Set'] == 'set3'
sort_run = data['Workload'] == 'sort_run'
sort_run = data[dataset & sort_run]
sort_run.reset_index(drop=True, inplace = True)
sort_run.plot(y='CPU', title = "sort_run_set3_CPU", use_index=True)
sort_run.plot(y='Mem', title = "sort_run_set3_Mem", use_index=True)

# Sort Run - set4

dataset = data['Set'] == 'set4'
sort_run = data['Workload'] == 'sort_run'
sort_run = data[dataset & sort_run]
sort_run.reset_index(drop=True, inplace = True)
sort_run.plot(y='CPU', title = "sort_run_set4_CPU", use_index=True)
sort_run.plot(y='Mem', title = "sort_run_set4_Mem", use_index=True)

# Sort Run - set5

dataset = data['Set'] == 'set5'
sort_run = data['Workload'] == 'sort_run'
sort_run = data[dataset & sort_run]
sort_run.reset_index(drop=True, inplace = True)
sort_run.plot(y='CPU', title = "sort_run_set5_CPU", use_index=True)
sort_run.plot(y='Mem', title = "sort_run_set5_Mem", use_index=True)

# Sort Run - set6

dataset = data['Set'] == 'set6'
sort_run = data['Workload'] == 'sort_run'
sort_run = data[dataset & sort_run]
sort_run.reset_index(drop=True, inplace = True)
sort_run.plot(y='CPU', title = "sort_run_set6_CPU", use_index=True)
sort_run.plot(y='Mem', title = "sort_run_set6_Mem", use_index=True)

# Sort Run - set7

dataset = data['Set'] == 'set7'
sort_run = data['Workload'] == 'sort_run'
sort_run = data[dataset & sort_run]
sort_run.reset_index(drop=True, inplace = True)
sort_run.plot(y='CPU', title = "sort_run_set7_CPU", use_index=True)
sort_run.plot(y='Mem', title = "sort_run_set7_Mem", use_index=True)

# Sort Run - set8

dataset = data['Set'] == 'set8'
sort_run = data['Workload'] == 'sort_run'
sort_run = data[dataset & sort_run]
sort_run.reset_index(drop=True, inplace = True)
sort_run.plot(y='CPU', title = "sort_run_set8_CPU", use_index=True)
sort_run.plot(y='Mem', title = "sort_run_set8_Mem", use_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a6263278b521> in <module>()
#      59 sort_run = data[dataset & sort_run]
#      60 sort_run.reset_index(drop=True, inplace = True)
# ---> 61 sort_run.plot(y='CPU', title = "sort_run_set7_CPU", use_index=True)
#      62 sort_run.plot(y='Mem', title = "sort_run_set7_Mem", use_index=True)
#      63
#
# /home/shaanzie/.local/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# ...

# %%
# Sort Run - Set 1

set1 = data['Set'] == 'set1'
wc_run = data['Workload'] == 'wc_run'
wc_run = data[set1 & wc_run]
wc_run.plot(x = 'Timestamp', y='CPU', title = "wc_run_set1_CPU")
wc_run.plot(x = 'Timestamp', y='Mem', title = "wc_run_set1_Mem")
4
# Sort Run - Set 2

dataset = data['Set'] == 'set2'
wc_run = data['Workload'] == 'wc_run'
wc_run = data[dataset & wc_run]

wc_run.plot(x = 'Timestamp', y='CPU', title = "wc_run_set2_CPU")
wc_run.plot(x = 'Timestamp', y='Mem', title = "wc_run_set2_Mem")

# Sort Run - set3

dataset = data['Set'] == 'set3'
wc_run = data['Workload'] == 'wc_run'
wc_run = data[dataset & wc_run]

wc_run.plot(x = 'Timestamp', y='CPU', title = "wc_run_set3_CPU")
wc_run.plot(x = 'Timestamp', y='Mem', title = "wc_run_set3_Mem")

# Sort Run - set4

dataset = data['Set'] == 'set4'
wc_run = data['Workload'] == 'wc_run'
wc_run = data[dataset & wc_run]

wc_run.plot(x = 'Timestamp', y='CPU', title = "wc_run_set4_CPU")
wc_run.plot(x = 'Timestamp', y='Mem', title = "wc_run_set4_Mem")

# Sort Run - set5

dataset = data['Set'] == 'set5'
wc_run = data['Workload'] == 'wc_run'
wc_run = data[dataset & wc_run]

wc_run.plot(x = 'Timestamp', y='CPU', title = "wc_run_set5_CPU")
wc_run.plot(x = 'Timestamp', y='Mem', title = "wc_run_set5_Mem")

# Sort Run - set6

dataset = data['Set'] == 'set6'
wc_run = data['Workload'] == 'wc_run'
wc_run = data[dataset & wc_run]

wc_run.plot(x = 'Timestamp', y='CPU', title = "wc_run_set6_CPU")
wc_run.plot(x = 'Timestamp', y='Mem', title = "wc_run_set6_Mem")

# Sort Run - set7

dataset = data['Set'] == 'set7'
wc_run = data['Workload'] == 'wc_run'
wc_run = data[dataset & wc_run]

wc_run.plot(x = 'Timestamp', y='CPU', title = "wc_run_set7_CPU")
wc_run.plot(x = 'Timestamp', y='Mem', title = "wc_run_set7_Mem")

# Sort Run - set8

dataset = data['Set'] == 'set8'
wc_run = data['Workload'] == 'wc_run'
wc_run = data[dataset & wc_run]

wc_run.plot(x = 'Timestamp', y='CPU', title = "wc_run_set8_CPU")
wc_run.plot(x = 'Timestamp', y='Mem', title = "wc_run_set8_Mem")

# %%
# Sort Run - Set 1

set1 = data['Set'] == 'set1'
cc_run = data['Workload'] == 'cc_run'
cc_run = data[set1 & cc_run]
cc_run.plot(x = 'Timestamp', y='CPU', title = "cc_run_set1_CPU")
cc_run.plot(x = 'Timestamp', y='Mem', title = "cc_run_set1_Mem")

# Sort Run - Set 2

dataset = data['Set'] == 'set2'
cc_run = data['Workload'] == 'cc_run'
cc_run = data[dataset & cc_run]

cc_run.plot(x = 'Timestamp', y='CPU', title = "cc_run_set2_CPU")
cc_run.plot(x = 'Timestamp', y='Mem', title = "cc_run_set2_Mem")

# Sort Run - set3

dataset = data['Set'] == 'set3'
cc_run = data['Workload'] == 'cc_run'
cc_run = data[dataset & cc_run]

cc_run.plot(x = 'Timestamp', y='CPU', title = "cc_run_set3_CPU")
cc_run.plot(x = 'Timestamp', y='Mem', title = "cc_run_set3_Mem")

# Sort Run - set4

dataset = data['Set'] == 'set4'
cc_run = data['Workload'] == 'cc_run'
cc_run = data[dataset & cc_run]

cc_run.plot(x = 'Timestamp', y='CPU', title = "cc_run_set4_CPU")
cc_run.plot(x = 'Timestamp', y='Mem', title = "cc_run_set4_Mem")

# Sort Run - set5

dataset = data['Set'] == 'set5'
cc_run = data['Workload'] == 'cc_run'
cc_run = data[dataset & cc_run]

cc_run.plot(x = 'Timestamp', y='CPU', title = "cc_run_set5_CPU")
cc_run.plot(x = 'Timestamp', y='Mem', title = "cc_run_set5_Mem")

# Sort Run - set6

dataset = data['Set'] == 'set6'
cc_run = data['Workload'] == 'cc_run'
cc_run = data[dataset & cc_run]

cc_run.plot(x = 'Timestamp', y='CPU', title = "cc_run_set6_CPU")
cc_run.plot(x = 'Timestamp', y='Mem', title = "cc_run_set6_Mem")

# Sort Run - set7

dataset = data['Set'] == 'set7'
cc_run = data['Workload'] == 'cc_run'
cc_run = data[dataset & cc_run]

cc_run.plot(x = 'Timestamp', y='CPU', title = "cc_run_set7_CPU")
cc_run.plot(x = 'Timestamp', y='Mem', title = "cc_run_set7_Mem")

# Sort Run - set8

dataset = data['Set'] == 'set8'
cc_run = data['Workload'] == 'cc_run'
cc_run = data[dataset & cc_run]

cc_run.plot(x = 'Timestamp', y='CPU', title = "cc_run_set8_CPU")
cc_run.plot(x = 'Timestamp', y='Mem', title = "cc_run_set8_Mem")

# %%
# Sort Run - Set 1

set1 = data['Set'] == 'set1'
randsample_run = data['Workload'] == 'randsample_run'
randsample_run = data[set1 & randsample_run]
randsample_run.plot(x = 'Timestamp', y='CPU', title = "randsample_run_set1_CPU")
randsample_run.plot(x = 'Timestamp', y='Mem', title = "randsample_run_set1_Mem")

# Sort Run - Set 2

dataset = data['Set'] == 'set2'
randsample_run = data['Workload'] == 'randsample_run'
randsample_run = data[dataset & randsample_run]

randsample_run.plot(x = 'Timestamp', y='CPU', title = "randsample_run_set2_CPU")
randsample_run.plot(x = 'Timestamp', y='Mem', title = "randsample_run_set2_Mem")

# Sort Run - set3

dataset = data['Set'] == 'set3'
randsample_run = data['Workload'] == 'randsample_run'
randsample_run = data[dataset & randsample_run]

randsample_run.plot(x = 'Timestamp', y='CPU', title = "randsample_run_set3_CPU")
randsample_run.plot(x = 'Timestamp', y='Mem', title = "randsample_run_set3_Mem")

# Sort Run - set4

dataset = data['Set'] == 'set4'
randsample_run = data['Workload'] == 'randsample_run'
randsample_run = data[dataset & randsample_run]

randsample_run.plot(x = 'Timestamp', y='CPU', title = "randsample_run_set4_CPU")
randsample_run.plot(x = 'Timestamp', y='Mem', title = "randsample_run_set4_Mem")

# Sort Run - set5

dataset = data['Set'] == 'set5'
randsample_run = data['Workload'] == 'randsample_run'
randsample_run = data[dataset & randsample_run]

randsample_run.plot(x = 'Timestamp', y='CPU', title = "randsample_run_set5_CPU")
randsample_run.plot(x = 'Timestamp', y='Mem', title = "randsample_run_set5_Mem")

# Sort Run - set6

dataset = data['Set'] == 'set6'
randsample_run = data['Workload'] == 'randsample_run'
randsample_run = data[dataset & randsample_run]

randsample_run.plot(x = 'Timestamp', y='CPU', title = "randsample_run_set6_CPU")
randsample_run.plot(x = 'Timestamp', y='Mem', title = "randsample_run_set6_Mem")

# Sort Run - set7

dataset = data['Set'] == 'set7'
randsample_run = data['Workload'] == 'randsample_run'
randsample_run = data[dataset & randsample_run]

randsample_run.plot(x = 'Timestamp', y='CPU', title = "randsample_run_set7_CPU")
randsample_run.plot(x = 'Timestamp', y='Mem', title = "randsample_run_set7_Mem")

# Sort Run - set8

dataset = data['Set'] == 'set8'
randsample_run = data['Workload'] == 'randsample_run'
randsample_run = data[dataset & randsample_run]

randsample_run.plot(x = 'Timestamp', y='CPU', title = "randsample_run_set8_CPU")
randsample_run.plot(x = 'Timestamp', y='Mem', title = "randsample_run_set8_Mem")

# %%
# Sort Run - Set 1

set1 = data['Set'] == 'set1'
md5_run = data['Workload'] == 'md5_run'
md5_run = data[set1 & md5_run]
md5_run.plot(x = 'Timestamp', y='CPU', title = "md5_run_set1_CPU")
md5_run.plot(x = 'Timestamp', y='Mem', title = "md5_run_set1_Mem")

# Sort Run - Set 2

dataset = data['Set'] == 'set2'
md5_run = data['Workload'] == 'md5_run'
md5_run = data[dataset & md5_run]

md5_run.plot(x = 'Timestamp', y='CPU', title = "md5_run_set2_CPU")
md5_run.plot(x = 'Timestamp', y='Mem', title = "md5_run_set2_Mem")

# Sort Run - set3

dataset = data['Set'] == 'set3'
md5_run = data['Workload'] == 'md5_run'
md5_run = data[dataset & md5_run]

md5_run.plot(x = 'Timestamp', y='CPU', title = "md5_run_set3_CPU")
md5_run.plot(x = 'Timestamp', y='Mem', title = "md5_run_set3_Mem")

# Sort Run - set4

dataset = data['Set'] == 'set4'
md5_run = data['Workload'] == 'md5_run'
md5_run = data[dataset & md5_run]

md5_run.plot(x = 'Timestamp', y='CPU', title = "md5_run_set4_CPU")
md5_run.plot(x = 'Timestamp', y='Mem', title = "md5_run_set4_Mem")

# Sort Run - set5

dataset = data['Set'] == 'set5'
md5_run = data['Workload'] == 'md5_run'
md5_run = data[dataset & md5_run]

md5_run.plot(x = 'Timestamp', y='CPU', title = "md5_run_set5_CPU")
md5_run.plot(x = 'Timestamp', y='Mem', title = "md5_run_set5_Mem")

# Sort Run - set6

dataset = data['Set'] == 'set6'
md5_run = data['Workload'] == 'md5_run'
md5_run = data[dataset & md5_run]

md5_run.plot(x = 'Timestamp', y='CPU', title = "md5_run_set6_CPU")
md5_run.plot(x = 'Timestamp', y='Mem', title = "md5_run_set6_Mem")

# Sort Run - set7

dataset = data['Set'] == 'set7'
md5_run = data['Workload'] == 'md5_run'
md5_run = data[dataset & md5_run]

md5_run.plot(x = 'Timestamp', y='CPU', title = "md5_run_set7_CPU")
md5_run.plot(x = 'Timestamp', y='Mem', title = "md5_run_set7_Mem")

# Sort Run - set8

dataset = data['Set'] == 'set8'
md5_run = data['Workload'] == 'md5_run'
md5_run = data[dataset & md5_run]

md5_run.plot(x = 'Timestamp', y='CPU', title = "md5_run_set8_CPU")
md5_run.plot(x = 'Timestamp', y='Mem', title = "md5_run_set8_Mem")

# %%
# Sort Run - Set 1

set1 = data['Set'] == 'set1'
grep_run = data['Workload'] == 'grep_run'
grep_run = data[set1 & grep_run]
grep_run.plot(x = 'Timestamp', y='CPU', title = "grep_run_set1_CPU")
grep_run.plot(x = 'Timestamp', y='Mem', title = "grep_run_set1_Mem")

# Sort Run - Set 2

dataset = data['Set'] == 'set2'
grep_run = data['Workload'] == 'grep_run'
grep_run = data[dataset & grep_run]

grep_run.plot(x = 'Timestamp', y='CPU', title = "grep_run_set2_CPU")
grep_run.plot(x = 'Timestamp', y='Mem', title = "grep_run_set2_Mem")

# Sort Run - set3

dataset = data['Set'] == 'set3'
grep_run = data['Workload'] == 'grep_run'
grep_run = data[dataset & grep_run]

grep_run.plot(x = 'Timestamp', y='CPU', title = "grep_run_set3_CPU")
grep_run.plot(x = 'Timestamp', y='Mem', title = "grep_run_set3_Mem")

# Sort Run - set4

dataset = data['Set'] == 'set4'
grep_run = data['Workload'] == 'grep_run'
grep_run = data[dataset & grep_run]

grep_run.plot(x = 'Timestamp', y='CPU', title = "grep_run_set4_CPU")
grep_run.plot(x = 'Timestamp', y='Mem', title = "grep_run_set4_Mem")

# Sort Run - set5

dataset = data['Set'] == 'set5'
grep_run = data['Workload'] == 'grep_run'
grep_run = data[dataset & grep_run]

grep_run.plot(x = 'Timestamp', y='CPU', title = "grep_run_set5_CPU")
grep_run.plot(x = 'Timestamp', y='Mem', title = "grep_run_set5_Mem")

# Sort Run - set6

dataset = data['Set'] == 'set6'
grep_run = data['Workload'] == 'grep_run'
grep_run = data[dataset & grep_run]

grep_run.plot(x = 'Timestamp', y='CPU', title = "grep_run_set6_CPU")
grep_run.plot(x = 'Timestamp', y='Mem', title = "grep_run_set6_Mem")

# Sort Run - set7

dataset = data['Set'] == 'set7'
grep_run = data['Workload'] == 'grep_run'
grep_run = data[dataset & grep_run]

grep_run.plot(x = 'Timestamp', y='CPU', title = "grep_run_set7_CPU")
grep_run.plot(x = 'Timestamp', y='Mem', title = "grep_run_set7_Mem")

# Sort Run - set8

dataset = data['Set'] == 'set8'
grep_run = data['Workload'] == 'grep_run'
grep_run = data[dataset & grep_run]

grep_run.plot(x = 'Timestamp', y='CPU', title = "grep_run_set8_CPU")
grep_run.plot(x = 'Timestamp', y='Mem', title = "grep_run_set8_Mem")

# %%
# Sort Run - Set 1

set1 = data['Set'] == 'set1'
fft0_5_run = data['Workload'] == 'fft0_5_run'
fft0_5_run = data[set1 & fft0_5_run]
fft0_5_run.plot(x = 'Timestamp', y='CPU', title = "fft0_5_run_set1_CPU")
fft0_5_run.plot(x = 'Timestamp', y='Mem', title = "fft0_5_run_set1_Mem")

# Sort Run - Set 2

dataset = data['Set'] == 'set2'
fft0_5_run = data['Workload'] == 'fft0_5_run'
fft0_5_run = data[dataset & fft0_5_run]

fft0_5_run.plot(x = 'Timestamp', y='CPU', title = "fft0_5_run_set2_CPU")
fft0_5_run.plot(x = 'Timestamp', y='Mem', title = "fft0_5_run_set2_Mem")

# Sort Run - set3

dataset = data['Set'] == 'set3'
fft0_5_run = data['Workload'] == 'fft0_5_run'
fft0_5_run = data[dataset & fft0_5_run]

fft0_5_run.plot(x = 'Timestamp', y='CPU', title = "fft0_5_run_set3_CPU")
fft0_5_run.plot(x = 'Timestamp', y='Mem', title = "fft0_5_run_set3_Mem")

# Sort Run - set4

dataset = data['Set'] == 'set4'
fft0_5_run = data['Workload'] == 'fft0_5_run'
fft0_5_run = data[dataset & fft0_5_run]

fft0_5_run.plot(x = 'Timestamp', y='CPU', title = "fft0_5_run_set4_CPU")
fft0_5_run.plot(x = 'Timestamp', y='Mem', title = "fft0_5_run_set4_Mem")

# Sort Run - set5

dataset = data['Set'] == 'set5'
fft0_5_run = data['Workload'] == 'fft0_5_run'
fft0_5_run = data[dataset & fft0_5_run]

fft0_5_run.plot(x = 'Timestamp', y='CPU', title = "fft0_5_run_set5_CPU")
fft0_5_run.plot(x = 'Timestamp', y='Mem', title = "fft0_5_run_set5_Mem")

# Sort Run - set6

dataset = data['Set'] == 'set6'
fft0_5_run = data['Workload'] == 'fft0_5_run'
fft0_5_run = data[dataset & fft0_5_run]

fft0_5_run.plot(x = 'Timestamp', y='CPU', title = "fft0_5_run_set6_CPU")
fft0_5_run.plot(x = 'Timestamp', y='Mem', title = "fft0_5_run_set6_Mem")

# Sort Run - set7

dataset = data['Set'] == 'set7'
fft0_5_run = data['Workload'] == 'fft0_5_run'
fft0_5_run = data[dataset & fft0_5_run]

fft0_5_run.plot(x = 'Timestamp', y='CPU', title = "fft0_5_run_set7_CPU")
fft0_5_run.plot(x = 'Timestamp', y='Mem', title = "fft0_5_run_set7_Mem")

# Sort Run - set8

dataset = data['Set'] == 'set8'
fft0_5_run = data['Workload'] == 'fft0_5_run'
fft0_5_run = data[dataset & fft0_5_run]

fft0_5_run.plot(x = 'Timestamp', y='CPU', title = "fft0_5_run_set8_CPU")
fft0_5_run.plot(x = 'Timestamp', y='Mem', title = "fft0_5_run_set8_Mem")

# %%
# Sort Run - Set 1

set1 = data['Set'] == 'set1'
matmult0_5_run = data['Workload'] == 'matmult0_5_run'
matmult0_5_run = data[set1 & matmult0_5_run]
matmult0_5_run.plot(x = 'Timestamp', y='CPU', title = "matmult0_5_run_set1_CPU")
matmult0_5_run.plot(x = 'Timestamp', y='Mem', title = "matmult0_5_run_set1_Mem")

# Sort Run - Set 2

dataset = data['Set'] == 'set2'
matmult0_5_run = data['Workload'] == 'matmult0_5_run'
matmult0_5_run = data[dataset & matmult0_5_run]

matmult0_5_run.plot(x = 'Timestamp', y='CPU', title = "matmult0_5_run_set2_CPU")
matmult0_5_run.plot(x = 'Timestamp', y='Mem', title = "matmult0_5_run_set2_Mem")

# Sort Run - set3

dataset = data['Set'] == 'set3'
matmult0_5_run = data['Workload'] == 'matmult0_5_run'
matmult0_5_run = data[dataset & matmult0_5_run]

matmult0_5_run.plot(x = 'Timestamp', y='CPU', title = "matmult0_5_run_set3_CPU")
matmult0_5_run.plot(x = 'Timestamp', y='Mem', title = "matmult0_5_run_set3_Mem")

# Sort Run - set4

dataset = data['Set'] == 'set4'
matmult0_5_run = data['Workload'] == 'matmult0_5_run'
matmult0_5_run = data[dataset & matmult0_5_run]

matmult0_5_run.plot(x = 'Timestamp', y='CPU', title = "matmult0_5_run_set4_CPU")
matmult0_5_run.plot(x = 'Timestamp', y='Mem', title = "matmult0_5_run_set4_Mem")

# Sort Run - set5

dataset = data['Set'] == 'set5'
matmult0_5_run = data['Workload'] == 'matmult0_5_run'
matmult0_5_run = data[dataset & matmult0_5_run]

matmult0_5_run.plot(x = 'Timestamp', y='CPU', title = "matmult0_5_run_set5_CPU")
matmult0_5_run.plot(x = 'Timestamp', y='Mem', title = "matmult0_5_run_set5_Mem")

# Sort Run - set6

dataset = data['Set'] == 'set6'
matmult0_5_run = data['Workload'] == 'matmult0_5_run'
matmult0_5_run = data[dataset & matmult0_5_run]

matmult0_5_run.plot(x = 'Timestamp', y='CPU', title = "matmult0_5_run_set6_CPU")
matmult0_5_run.plot(x = 'Timestamp', y='Mem', title = "matmult0_5_run_set6_Mem")

# Sort Run - set7

dataset = data['Set'] == 'set7'
matmult0_5_run = data['Workload'] == 'matmult0_5_run'
matmult0_5_run = data[dataset & matmult0_5_run]

matmult0_5_run.plot(x = 'Timestamp', y='CPU', title = "matmult0_5_run_set7_CPU")
matmult0_5_run.plot(x = 'Timestamp', y='Mem', title = "matmult0_5_run_set7_Mem")

# Sort Run - set8

dataset = data['Set'] == 'set8'
matmult0_5_run = data['Workload'] == 'matmult0_5_run'
matmult0_5_run = data[dataset & matmult0_5_run]

matmult0_5_run.plot(x = 'Timestamp', y='CPU', title = "matmult0_5_run_set8_CPU")
matmult0_5_run.plot(x = 'Timestamp', y='Mem', title = "matmult0_5_run_set8_Mem")
